# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score, get_scorer_names, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier, ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB, CategoricalNB
from xgboost import XGBClassifier
import xgboost as xgb
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from statistics import mode as md

# %%
X_test = pd.read_csv("../tanzanian_water_wells/X_test.csv")
X_train = pd.read_csv("../tanzanian_water_wells/X_train.csv")
y_train = pd.read_csv("../tanzanian_water_wells/y_train.csv")

df = pd.concat([X_train, y_train], axis=1)

# %%
desc = {'amount_tsh': 'Total static head (amount water available to waterpoint)',
                    'date_recorded': 'The date the row was entered',
                    'funder': 'Who funded the well',
                    'gps_height': 'Altitude of the well',
                    'installer': 'Organization that installed the well',
                    'longitude': 'GPS coordinate',
                    'latitude': 'GPS coordinate',
                    'wpt_name': 'Name of the waterpoint if there is one',
                    'subvillage': 'Geographic location',
                    'region': 'Geographic location',
                    'region_code': 'Geographic location (coded)',
                    'district_code': 'Geographic location (coded)',
                    'lga': 'Geographic location',
                    'ward': 'Geographic location',
                    'population': 'Population around the well',
                    'public_meeting': 'True/False',
                    'recorded_by': 'Group entering this row of data',
                    'scheme_management': 'Who operates the waterpoint',
                    'scheme_name': 'Who operates the waterpoint',
                    'permit': 'If the waterpoint is permitted',
                    'construction_year': 'Year the waterpoint was constructed',
                    'extraction_type': 'The kind of extraction the waterpoint uses',
                    'extraction_type_group': 'The kind of extraction the waterpoint uses',
                    'extraction_type_class': 'The kind of extraction the waterpoint uses',
                    'management': 'How the waterpoint is managed',
                    'management_group': 'How the waterpoint is managed',
                    'payment': 'What the water costs',
                    'payment_type': 'What the water costs',
                    'water_quality': 'The quality of the water',
                    'quality_group': 'The quality of the water',
                    'quantity': 'The quantity of water',
                    'quantity_group': 'The quantity of water',
                    'source': 'The source of the water',
                    'source_type': 'The source of the water',
                    'source_class': 'The source of the water',
                    'waterpoint_type': 'The kind of waterpoint',
                    'waterpoint_type_group': 'The kind of waterpoint'}

# %%
# Eliminating null values

df.funder.fillna("Unknown", inplace=True)
df.installer.fillna("Unknown", inplace=True)
df.scheme_management.fillna("None", inplace=True)
df.permit.fillna('Unknown', inplace=True)
df.scheme_name.fillna('Unknown', inplace=True)
df.subvillage.fillna('Unknown', inplace=True)
df.public_meeting.fillna('Unknown', inplace=True)

# %% [markdown]
# # Defining the train and test sets

# %%
X = df.copy()

columns = ['amount_tsh', 'gps_height', 'population', 'region', 'lga', 
           'scheme_management', 'permit', 'construction_year',
           'extraction_type_group', 'payment', 'management', 
           'quality_group', 'quantity', 'source', 'waterpoint_type']

X = X[columns]

# X['public_meeting'] = X['public_meeting'].map({True: 'Yes', False: 'No', 'Unknown': 'Unknown'})
X['permit'] = X['permit'].map({True: 'Yes', False: 'No', 'Unknown': 'Unknown'})
X['gps_height'] = X['gps_height'].astype('float64')
# X['district_code'] = X['district_code'].astype('float64')
X['population'] = X['population'].astype('float64')
# X['district_code'] = X['district_code'].astype('object')

X_cat = X.drop(list(X.select_dtypes(['float64']).columns), axis=1)
X_numeric = X[list(X.select_dtypes(['float64']).columns)]

y = df['status_group']

X_cat = pd.get_dummies(X_cat)

X = pd.concat([X_numeric, X_cat], axis=1)

X_train, X_test, y_train, y_test = train_test_split(X, y)

scaler = StandardScaler()
scaler.fit(X_train)
X_train = pd.DataFrame(scaler.transform(X_train),
                index = X_train.index,
                columns = X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test),
                index = X_test.index,
                columns = X_test.columns)

X_train.reset_index(inplace=True, drop=True)
y_train = y_train.reset_index(drop=True)

# %%
X_train_sample = X_train.sample(n=1000, random_state=42)
y_train_sample = y_train.iloc[list(X_train_sample.index)]

# %% [markdown]
# # Decision Tree

# %%
dtc = DecisionTreeClassifier(random_state=42)

# %%
param_grid = {
    'min_samples_split': [1, 5, 10, 20, 40],
    'min_samples_leaf': [1, 5, 10, 20],  
    'max_features': [5, 10, 50, 100, None], 
    'max_depth': [1, 3, 5, 7, 10, None]
}

gs_dtc = GridSearchCV(dtc, param_grid, cv=3, verbose=10)
gs_dtc.fit(X_train, y_train)
# Out:
# Fitting 3 folds for each of 600 candidates, totalling 1800 fits
# [CV 1/3; 1/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=1
# [CV 1/3; 1/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 1/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=1
# [CV 2/3; 1/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 1/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=1
# [CV 3/3; 1/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 2/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=5
# [CV 1/3; 2/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 2/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=5
# [CV 2/3; 2/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.548 total time=   0.0s
# [CV 3/3; 2/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=5
# [CV 3/3; 2/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 1/3; 3/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 3/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 2/3; 3/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 3/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.596 total time=   0.0s
# [CV 3/3; 3/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 3/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 1/3; 4/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 4/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=20;, score=0.640 total time=   0.0s
# [CV 2/3; 4/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 4/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 3/3; 4/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 4/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/3; 5/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=40
# [CV 1/3; 5/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=40;, score=0.555 total time=   0.0s
# [CV 2/3; 5/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=40
# [CV 2/3; 5/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 3/3; 5/600] START max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=40
# [CV 3/3; 5/600] END max_depth=1, max_features=5, min_samples_leaf=1, min_samples_split=40;, score=0.551 total time=   0.0s
# [CV 1/3; 6/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=1
# [CV 1/3; 6/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 6/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=1
# [CV 2/3; 6/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 6/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=1
# [CV 3/3; 6/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 7/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=5
# [CV 1/3; 7/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.546 total time=   0.0s
# [CV 2/3; 7/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=5
# [CV 2/3; 7/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.548 total time=   0.0s
# [CV 3/3; 7/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=5
# [CV 3/3; 7/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=5;, score=0.647 total time=   0.0s
# [CV 1/3; 8/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 8/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 2/3; 8/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 8/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 8/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 8/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 1/3; 9/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 9/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 2/3; 9/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 9/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 3/3; 9/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 9/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/3; 10/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=40
# [CV 1/3; 10/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 10/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=40
# [CV 2/3; 10/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=40;, score=0.548 total time=   0.0s
# [CV 3/3; 10/600] START max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=40
# [CV 3/3; 10/600] END max_depth=1, max_features=5, min_samples_leaf=5, min_samples_split=40;, score=0.551 total time=   0.0s
# [CV 1/3; 11/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=1
# [CV 1/3; 11/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 11/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=1
# [CV 2/3; 11/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 11/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=1
# [CV 3/3; 11/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 12/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=5
# [CV 1/3; 12/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 12/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=5
# [CV 2/3; 12/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.548 total time=   0.0s
# [CV 3/3; 12/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=5
# [CV 3/3; 12/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 1/3; 13/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 13/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.557 total time=   0.0s
# [CV 2/3; 13/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 13/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 13/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 13/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 1/3; 14/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 14/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 2/3; 14/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 14/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 3/3; 14/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 14/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=20;, score=0.554 total time=   0.0s
# [CV 1/3; 15/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=40
# [CV 1/3; 15/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 15/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=40
# [CV 2/3; 15/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 3/3; 15/600] START max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=40
# [CV 3/3; 15/600] END max_depth=1, max_features=5, min_samples_leaf=10, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 1/3; 16/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=1
# [CV 1/3; 16/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 16/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=1
# [CV 2/3; 16/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 16/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=1
# [CV 3/3; 16/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 17/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=5
# [CV 1/3; 17/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 17/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=5
# [CV 2/3; 17/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=5;, score=0.642 total time=   0.0s
# [CV 3/3; 17/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=5
# [CV 3/3; 17/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 1/3; 18/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=10
# [CV 1/3; 18/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 2/3; 18/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=10
# [CV 2/3; 18/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 18/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=10
# [CV 3/3; 18/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=10;, score=0.545 total time=   0.0s
# [CV 1/3; 19/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=20
# [CV 1/3; 19/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=20;, score=0.551 total time=   0.0s
# [CV 2/3; 19/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=20
# [CV 2/3; 19/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=20;, score=0.642 total time=   0.0s
# [CV 3/3; 19/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=20
# [CV 3/3; 19/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=20;, score=0.560 total time=   0.0s
# [CV 1/3; 20/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=40
# [CV 1/3; 20/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 20/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=40
# [CV 2/3; 20/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=40;, score=0.544 total time=   0.0s
# [CV 3/3; 20/600] START max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=40
# [CV 3/3; 20/600] END max_depth=1, max_features=5, min_samples_leaf=20, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 1/3; 21/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=1
# [CV 1/3; 21/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 21/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=1
# [CV 2/3; 21/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 21/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=1
# [CV 3/3; 21/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 22/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=5
# [CV 1/3; 22/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 22/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=5
# [CV 2/3; 22/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=5;, score=0.563 total time=   0.0s
# [CV 3/3; 22/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=5
# [CV 3/3; 22/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=5;, score=0.647 total time=   0.0s
# [CV 1/3; 23/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 23/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=10;, score=0.640 total time=   0.0s
# [CV 2/3; 23/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 23/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 23/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 23/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 1/3; 24/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 24/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=20;, score=0.616 total time=   0.0s
# [CV 2/3; 24/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 24/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 3/3; 24/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 24/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=20;, score=0.611 total time=   0.0s
# [CV 1/3; 25/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=40
# [CV 1/3; 25/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 25/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=40
# [CV 2/3; 25/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=40;, score=0.562 total time=   0.0s
# [CV 3/3; 25/600] START max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=40
# [CV 3/3; 25/600] END max_depth=1, max_features=10, min_samples_leaf=1, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 1/3; 26/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=1
# [CV 1/3; 26/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 26/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=1
# [CV 2/3; 26/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 26/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=1
# [CV 3/3; 26/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 27/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=5
# [CV 1/3; 27/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=5;, score=0.545 total time=   0.0s
# [CV 2/3; 27/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=5
# [CV 2/3; 27/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=5;, score=0.618 total time=   0.0s
# [CV 3/3; 27/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=5
# [CV 3/3; 27/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 1/3; 28/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 28/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=10;, score=0.557 total time=   0.0s
# [CV 2/3; 28/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 28/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 28/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 28/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=10;, score=0.544 total time=   0.0s
# [CV 1/3; 29/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 29/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=20;, score=0.596 total time=   0.0s
# [CV 2/3; 29/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 29/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 3/3; 29/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 29/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/3; 30/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=40
# [CV 1/3; 30/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 30/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=40
# [CV 2/3; 30/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=40;, score=0.563 total time=   0.0s
# [CV 3/3; 30/600] START max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=40
# [CV 3/3; 30/600] END max_depth=1, max_features=10, min_samples_leaf=5, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 1/3; 31/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=1
# [CV 1/3; 31/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 31/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=1
# [CV 2/3; 31/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 31/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=1
# [CV 3/3; 31/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 32/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=5
# [CV 1/3; 32/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 32/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=5
# [CV 2/3; 32/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=5;, score=0.546 total time=   0.0s
# [CV 3/3; 32/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=5
# [CV 3/3; 32/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 1/3; 33/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 33/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 2/3; 33/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 33/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 33/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 33/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=10;, score=0.544 total time=   0.0s
# [CV 1/3; 34/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 34/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=20;, score=0.551 total time=   0.0s
# [CV 2/3; 34/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 34/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 3/3; 34/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 34/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=20;, score=0.541 total time=   0.0s
# [CV 1/3; 35/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=40
# [CV 1/3; 35/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=40;, score=0.596 total time=   0.0s
# [CV 2/3; 35/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=40
# [CV 2/3; 35/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=40;, score=0.551 total time=   0.0s
# [CV 3/3; 35/600] START max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=40
# [CV 3/3; 35/600] END max_depth=1, max_features=10, min_samples_leaf=10, min_samples_split=40;, score=0.647 total time=   0.0s
# [CV 1/3; 36/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=1
# [CV 1/3; 36/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 36/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=1
# [CV 2/3; 36/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 36/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=1
# [CV 3/3; 36/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 37/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=5
# [CV 1/3; 37/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 37/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=5
# [CV 2/3; 37/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 3/3; 37/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=5
# [CV 3/3; 37/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=5;, score=0.547 total time=   0.0s
# [CV 1/3; 38/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=10
# [CV 1/3; 38/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=10;, score=0.616 total time=   0.0s
# [CV 2/3; 38/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=10
# [CV 2/3; 38/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=10;, score=0.554 total time=   0.0s
# [CV 3/3; 38/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=10
# [CV 3/3; 38/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 1/3; 39/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=20
# [CV 1/3; 39/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=20;, score=0.547 total time=   0.0s
# [CV 2/3; 39/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=20
# [CV 2/3; 39/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=20;, score=0.559 total time=   0.0s
# [CV 3/3; 39/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=20
# [CV 3/3; 39/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/3; 40/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=40
# [CV 1/3; 40/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=40;, score=0.596 total time=   0.0s
# [CV 2/3; 40/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=40
# [CV 2/3; 40/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=40;, score=0.618 total time=   0.0s
# [CV 3/3; 40/600] START max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=40
# [CV 3/3; 40/600] END max_depth=1, max_features=10, min_samples_leaf=20, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 1/3; 41/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=1
# [CV 1/3; 41/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 41/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=1
# [CV 2/3; 41/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 41/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=1
# [CV 3/3; 41/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 42/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=5
# [CV 1/3; 42/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 2/3; 42/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=5
# [CV 2/3; 42/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 3/3; 42/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=5
# [CV 3/3; 42/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 1/3; 43/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 43/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=10;, score=0.596 total time=   0.0s
# [CV 2/3; 43/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 43/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=10;, score=0.613 total time=   0.0s
# [CV 3/3; 43/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 43/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 1/3; 44/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 44/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 2/3; 44/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 44/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=20;, score=0.618 total time=   0.0s
# [CV 3/3; 44/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 44/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=20;, score=0.611 total time=   0.0s
# [CV 1/3; 45/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=40
# [CV 1/3; 45/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 45/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=40
# [CV 2/3; 45/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=40;, score=0.596 total time=   0.0s
# [CV 3/3; 45/600] START max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=40
# [CV 3/3; 45/600] END max_depth=1, max_features=50, min_samples_leaf=1, min_samples_split=40;, score=0.611 total time=   0.0s
# [CV 1/3; 46/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=1
# [CV 1/3; 46/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 46/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=1
# [CV 2/3; 46/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 46/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=1
# [CV 3/3; 46/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 47/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=5
# [CV 1/3; 47/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=5;, score=0.596 total time=   0.0s
# [CV 2/3; 47/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=5
# [CV 2/3; 47/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=5;, score=0.559 total time=   0.0s
# [CV 3/3; 47/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=5
# [CV 3/3; 47/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=5;, score=0.647 total time=   0.0s
# [CV 1/3; 48/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 48/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=10;, score=0.596 total time=   0.0s
# [CV 2/3; 48/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 48/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=10;, score=0.642 total time=   0.0s
# [CV 3/3; 48/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 48/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=10;, score=0.606 total time=   0.0s
# [CV 1/3; 49/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 49/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=20;, score=0.640 total time=   0.0s
# [CV 2/3; 49/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 49/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 3/3; 49/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 49/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=20;, score=0.606 total time=   0.0s
# [CV 1/3; 50/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=40
# [CV 1/3; 50/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 2/3; 50/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=40
# [CV 2/3; 50/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 3/3; 50/600] START max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=40
# [CV 3/3; 50/600] END max_depth=1, max_features=50, min_samples_leaf=5, min_samples_split=40;, score=0.593 total time=   0.0s
# [CV 1/3; 51/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=1
# [CV 1/3; 51/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 51/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=1
# [CV 2/3; 51/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 51/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=1
# [CV 3/3; 51/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 52/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=5
# [CV 1/3; 52/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=5;, score=0.616 total time=   0.0s
# [CV 2/3; 52/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=5
# [CV 2/3; 52/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 3/3; 52/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=5
# [CV 3/3; 52/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=5;, score=0.611 total time=   0.0s
# [CV 1/3; 53/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 53/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=10;, score=0.640 total time=   0.0s
# [CV 2/3; 53/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 53/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=10;, score=0.642 total time=   0.0s
# [CV 3/3; 53/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 53/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=10;, score=0.593 total time=   0.0s
# [CV 1/3; 54/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 54/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=20;, score=0.640 total time=   0.0s
# [CV 2/3; 54/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 54/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=20;, score=0.618 total time=   0.0s
# [CV 3/3; 54/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 54/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=20;, score=0.543 total time=   0.0s
# [CV 1/3; 55/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=40
# [CV 1/3; 55/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=40;, score=0.640 total time=   0.0s
# [CV 2/3; 55/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=40
# [CV 2/3; 55/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=40;, score=0.618 total time=   0.0s
# [CV 3/3; 55/600] START max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=40
# [CV 3/3; 55/600] END max_depth=1, max_features=50, min_samples_leaf=10, min_samples_split=40;, score=0.543 total time=   0.0s
# [CV 1/3; 56/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=1
# [CV 1/3; 56/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 56/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=1
# [CV 2/3; 56/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 56/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=1
# [CV 3/3; 56/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 57/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=5
# [CV 1/3; 57/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=5;, score=0.557 total time=   0.0s
# [CV 2/3; 57/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=5
# [CV 2/3; 57/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=5;, score=0.543 total time=   0.0s
# [CV 3/3; 57/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=5
# [CV 3/3; 57/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=5;, score=0.647 total time=   0.0s
# [CV 1/3; 58/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=10
# [CV 1/3; 58/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=10;, score=0.620 total time=   0.0s
# [CV 2/3; 58/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=10
# [CV 2/3; 58/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=10;, score=0.543 total time=   0.0s
# [CV 3/3; 58/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=10
# [CV 3/3; 58/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=10;, score=0.647 total time=   0.0s
# [CV 1/3; 59/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=20
# [CV 1/3; 59/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=20;, score=0.596 total time=   0.0s
# [CV 2/3; 59/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=20
# [CV 2/3; 59/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=20;, score=0.596 total time=   0.0s
# [CV 3/3; 59/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=20
# [CV 3/3; 59/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=20;, score=0.647 total time=   0.0s
# [CV 1/3; 60/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=40
# [CV 1/3; 60/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=40;, score=0.620 total time=   0.0s
# [CV 2/3; 60/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=40
# [CV 2/3; 60/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=40;, score=0.642 total time=   0.0s
# [CV 3/3; 60/600] START max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=40
# [CV 3/3; 60/600] END max_depth=1, max_features=50, min_samples_leaf=20, min_samples_split=40;, score=0.593 total time=   0.0s
# [CV 1/3; 61/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=1
# [CV 1/3; 61/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 61/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=1
# [CV 2/3; 61/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 61/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=1
# [CV 3/3; 61/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 62/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=5
# [CV 1/3; 62/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=5;, score=0.640 total time=   0.1s
# [CV 2/3; 62/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=5
# [CV 2/3; 62/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=5;, score=0.642 total time=   0.0s
# [CV 3/3; 62/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=5
# [CV 3/3; 62/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=5;, score=0.606 total time=   0.0s
# [CV 1/3; 63/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=10
# [CV 1/3; 63/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=10;, score=0.640 total time=   0.1s
# [CV 2/3; 63/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=10
# [CV 2/3; 63/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=10;, score=0.618 total time=   0.1s
# [CV 3/3; 63/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=10
# [CV 3/3; 63/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=10;, score=0.647 total time=   0.1s
# [CV 1/3; 64/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=20
# [CV 1/3; 64/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=20;, score=0.640 total time=   0.1s
# [CV 2/3; 64/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=20
# [CV 2/3; 64/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=20;, score=0.596 total time=   0.1s
# [CV 3/3; 64/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=20
# [CV 3/3; 64/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=20;, score=0.593 total time=   0.1s
# [CV 1/3; 65/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=40
# [CV 1/3; 65/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=40;, score=0.620 total time=   0.0s
# [CV 2/3; 65/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=40
# [CV 2/3; 65/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=40;, score=0.613 total time=   0.1s
# [CV 3/3; 65/600] START max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=40
# [CV 3/3; 65/600] END max_depth=1, max_features=100, min_samples_leaf=1, min_samples_split=40;, score=0.611 total time=   0.1s
# [CV 1/3; 66/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=1
# [CV 1/3; 66/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 66/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=1
# [CV 2/3; 66/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 66/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=1
# [CV 3/3; 66/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 67/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=5
# [CV 1/3; 67/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=5;, score=0.640 total time=   0.0s
# [CV 2/3; 67/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=5
# [CV 2/3; 67/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=5;, score=0.618 total time=   0.1s
# [CV 3/3; 67/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=5
# [CV 3/3; 67/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=5;, score=0.647 total time=   0.1s
# [CV 1/3; 68/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=10
# [CV 1/3; 68/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=10;, score=0.596 total time=   0.1s
# [CV 2/3; 68/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=10
# [CV 2/3; 68/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=10;, score=0.618 total time=   0.0s
# [CV 3/3; 68/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=10
# [CV 3/3; 68/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=10;, score=0.606 total time=   0.1s
# [CV 1/3; 69/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=20
# [CV 1/3; 69/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=20;, score=0.640 total time=   0.1s
# [CV 2/3; 69/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=20
# [CV 2/3; 69/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=20;, score=0.596 total time=   0.0s
# [CV 3/3; 69/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=20
# [CV 3/3; 69/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=20;, score=0.611 total time=   0.1s
# [CV 1/3; 70/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=40
# [CV 1/3; 70/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=40;, score=0.640 total time=   0.0s
# [CV 2/3; 70/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=40
# [CV 2/3; 70/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=40;, score=0.642 total time=   0.1s
# [CV 3/3; 70/600] START max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=40
# [CV 3/3; 70/600] END max_depth=1, max_features=100, min_samples_leaf=5, min_samples_split=40;, score=0.647 total time=   0.1s
# [CV 1/3; 71/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=1
# [CV 1/3; 71/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 71/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=1
# [CV 2/3; 71/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 71/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=1
# [CV 3/3; 71/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 72/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=5
# [CV 1/3; 72/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=5;, score=0.620 total time=   0.1s
# [CV 2/3; 72/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=5
# [CV 2/3; 72/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=5;, score=0.642 total time=   0.0s
# [CV 3/3; 72/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=5
# [CV 3/3; 72/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=5;, score=0.647 total time=   0.0s
# [CV 1/3; 73/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 73/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=10;, score=0.620 total time=   0.0s
# [CV 2/3; 73/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 73/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=10;, score=0.613 total time=   0.0s
# [CV 3/3; 73/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 73/600] END max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=10;, score=0.611 total time=   0.0s
# [CV 1/3; 74/600] START max_depth=1, max_features=100, min_samples_leaf=10, min_samples_split=20
# ...
# [CV 1/3; 591/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 591/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=1
# [CV 2/3; 591/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 591/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=1
# [CV 3/3; 591/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 592/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=5
# [CV 1/3; 592/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=0.756 total time=   0.4s
# [CV 2/3; 592/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=5
# [CV 2/3; 592/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=0.758 total time=   0.3s
# [CV 3/3; 592/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=5
# [CV 3/3; 592/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=5;, score=0.755 total time=   0.3s
# [CV 1/3; 593/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10
# [CV 1/3; 593/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=0.756 total time=   0.4s
# [CV 2/3; 593/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10
# [CV 2/3; 593/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=0.758 total time=   0.3s
# [CV 3/3; 593/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10
# [CV 3/3; 593/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=10;, score=0.754 total time=   0.3s
# [CV 1/3; 594/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20
# [CV 1/3; 594/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.756 total time=   0.4s
# [CV 2/3; 594/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20
# [CV 2/3; 594/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.758 total time=   0.3s
# [CV 3/3; 594/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20
# [CV 3/3; 594/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=20;, score=0.754 total time=   0.3s
# [CV 1/3; 595/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40
# [CV 1/3; 595/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40;, score=0.754 total time=   0.4s
# [CV 2/3; 595/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40
# [CV 2/3; 595/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40;, score=0.758 total time=   0.3s
# [CV 3/3; 595/600] START max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40
# [CV 3/3; 595/600] END max_depth=None, max_features=None, min_samples_leaf=10, min_samples_split=40;, score=0.753 total time=   0.3s
# [CV 1/3; 596/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=1
# [CV 1/3; 596/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 2/3; 596/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=1
# [CV 2/3; 596/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 3/3; 596/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=1
# [CV 3/3; 596/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=1;, score=nan total time=   0.0s
# [CV 1/3; 597/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=5
# [CV 1/3; 597/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=5;, score=0.751 total time=   0.4s
# [CV 2/3; 597/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=5
# [CV 2/3; 597/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=5;, score=0.760 total time=   0.3s
# [CV 3/3; 597/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=5
# [CV 3/3; 597/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=5;, score=0.748 total time=   0.3s
# [CV 1/3; 598/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=10
# [CV 1/3; 598/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=10;, score=0.751 total time=   0.4s
# [CV 2/3; 598/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=10
# [CV 2/3; 598/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=10;, score=0.759 total time=   0.3s
# [CV 3/3; 598/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=10
# [CV 3/3; 598/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=10;, score=0.748 total time=   0.3s
# [CV 1/3; 599/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=20
# [CV 1/3; 599/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=20;, score=0.751 total time=   0.4s
# [CV 2/3; 599/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=20
# [CV 2/3; 599/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=20;, score=0.759 total time=   0.3s
# [CV 3/3; 599/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=20
# [CV 3/3; 599/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=20;, score=0.748 total time=   0.3s
# [CV 1/3; 600/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=40
# [CV 1/3; 600/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=40;, score=0.751 total time=   0.4s
# [CV 2/3; 600/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=40
# [CV 2/3; 600/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=40;, score=0.760 total time=   0.3s
# [CV 3/3; 600/600] START max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=40
# [CV 3/3; 600/600] END max_depth=None, max_features=None, min_samples_leaf=20, min_samples_split=40;, score=0.748 total time=   0.3s
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 360 fits failed out of a total of 1800.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 360 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/tree/_classes.py", line 889, in fit
#     super().fit(
#   File "/Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/tree/_classes.py", line 177, in fit
#     self._validate_params()
#   File "/Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of DecisionTreeClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/angeloturri/opt/anaconda3/envs/learn-env/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan 0.54480359 0.56098765 0.575578   0.54965208        nan
#  0.58017957 0.54329966 0.54329966 0.54727273        nan 0.54480359
#  0.54796857 0.54691358 0.54329966        nan 0.57618406 0.54379349
#  0.5843771  0.54345679        nan 0.58428732 0.575578   0.59519641
#  0.54940516        nan 0.56859708 0.54819304 0.56094276 0.5498541
#         nan 0.54419753 0.54352413 0.55054994 0.59782267        nan
#  0.54439955 0.57104377 0.54971942 0.58581369        nan 0.54329966
#  0.5840853  0.59057239 0.58338945        nan 0.60056117 0.61488215
#  0.596633   0.55986532        nan 0.59001122 0.62502806 0.60044893
#  0.60044893        nan 0.5824018  0.6034119  0.61306397 0.61842873
#         nan 0.6295174  0.63488215 0.60983165 0.61452301        nan
#  0.63488215 0.60686869 0.61566779 0.64289562        nan 0.6362963
#  0.61452301 0.60260382 0.6034119         nan 0.58989899 0.64289562
#  0.6308642  0.61705948        nan 0.64289562 0.64289562 0.64289562
#  0.64289562        nan 0.64289562 0.64289562 0.64289562 0.64289562
#         nan 0.64289562 0.64289562 0.64289562 0.64289562        nan
#  0.64289562 0.64289562 0.64289562 0.64289562        nan 0.54920314
#  0.60372615 0.57679012 0.55400673        nan 0.56415264 0.54727273
#  0.5518743  0.57602694        nan 0.58592593 0.56347924 0.56
#  0.55986532        nan 0.56891134 0.59333333 0.55494949 0.56049383
#         nan 0.58217733 0.56130191 0.60159371 0.55542088        nan
#  0.59021324 0.56161616 0.59416386 0.60835017        nan 0.60159371
#  0.604422   0.5806734  0.58983165        nan 0.58657688 0.59782267
#  0.58868687 0.6050954         nan 0.64994388 0.66289562 0.65970819
#  0.67239057        nan 0.63602694 0.66641975 0.66709315 0.63782267
#         nan 0.68648709 0.62296296 0.64511785 0.64294052        nan
#  0.62799102 0.69265993 0.64015713 0.66062851        nan 0.6895174
#  0.66832772 0.67578002 0.67627385        nan 0.67714927 0.69088664
#  0.66814815 0.69378227        nan 0.67398429 0.68601571 0.69400673
#  0.65039282        nan 0.68859708 0.68208754 0.68011223 0.68635241
#         nan 0.6942312  0.6942312  0.69418631 0.69414141        nan
#  0.69418631 0.69418631 0.69418631 0.69414141        nan 0.69411897
#  0.69411897 0.69411897 0.69414141        nan 0.69400673 0.69400673
#  0.69400673 0.69400673        nan 0.58720539 0.59714927 0.59416386
#  0.57328844        nan 0.60531987 0.57138047 0.60888889 0.58971942
#         nan 0.59070707 0.58498316 0.59250281 0.5827385         nan
#  0.57301908 0.57032548 0.58960718 0.5769697         nan 0.58439955
#  0.61227834 0.59362514 0.63039282        nan 0.6284624  0.61479237
#  0.58511785 0.62233446        nan 0.60747475 0.65804714 0.62725028
#  0.60704826        nan 0.61616162 0.63699214 0.60345679 0.6176431
#         nan 0.67104377 0.69331089 0.68597082 0.68116723        nan
#  0.69072952 0.70421998 0.68314254 0.69420875        nan 0.6847138
#  0.6803367  0.65265993 0.66523008        nan 0.68722783 0.67818182
#  0.69885522 0.70195286        nan 0.70776655 0.70565657 0.70617284
#  0.70386083        nan 0.70368126 0.70534231 0.70457912 0.70781145
#         nan 0.70839506 0.70597082 0.70076319 0.68774411        nan
#  0.70446689 0.70751964 0.70585859 0.70740741        nan 0.7115376
#  0.71151515 0.71151515 0.71140292        nan 0.71151515 0.7115376
#  0.7114927  0.71140292        nan 0.71122334 0.71124579 0.71124579
#  0.7112009         nan 0.71108866 0.71106622 0.71108866 0.71108866
#         nan 0.59867565 0.58451178 0.59616162 0.615578          nan
#  0.62641975 0.61384961 0.616633   0.59239057        nan 0.60334456
#  0.64621773 0.61068462 0.57735129        nan 0.58011223 0.6128844
#  0.62801347 0.59106622        nan 0.64498316 0.64958474 0.61351291
#  0.62157127        nan 0.61476992 0.63007856 0.61575758 0.64819304
#         nan 0.64597082 0.61317621 0.62170595 0.63647587        nan
#  0.5976431  0.63916947 0.65084175 0.61564534        nan 0.70938272
#  0.7108193  0.71589226 0.71173962        nan 0.70237935 0.70803591
#  0.71144781 0.70570146        nan 0.71216611 0.70049383 0.70659933
#  0.71407407        nan 0.70554433 0.7138945  0.70395062 0.69575758
#         nan 0.71997755 0.72114478 0.71708193 0.7179349         nan
#  0.72044893 0.71133558 0.7173064  0.72094276        nan 0.7125477
#  0.72123457 0.72188552 0.72145903        nan 0.71818182 0.72260382
#  0.72116723 0.71400673        nan 0.72181818 0.72186308 0.72179574
#  0.7217284         nan 0.7217284  0.72175084 0.7216835  0.72152637
#         nan 0.72150393 0.72150393 0.72150393 0.72143659        nan
#  0.72143659 0.72148148 0.72145903 0.72145903        nan 0.65488215
#  0.6369248  0.64502806 0.66695847        nan 0.62565657 0.64204265
#  0.66469136 0.63326599        nan 0.63043771 0.60684624 0.63263749
#  0.62585859        nan 0.62148148 0.62650954 0.61225589 0.63717172
#         nan 0.6562514  0.63757576 0.66062851 0.67468013        nan
#  0.64718294 0.65732884 0.66071829 0.64803591        nan 0.671156
#  0.65138047 0.66271605 0.66924804        nan 0.6630303  0.67277217
#  0.64608305 0.67333333        nan 0.72446689 0.72700337 0.72781145
#  0.73039282        nan 0.72859708 0.72686869 0.7301908  0.72960718
#         nan 0.73133558 0.72857464 0.72727273 0.72635241        nan
#  0.72534231 0.7217284  0.72493827 0.72285073        nan 0.73034792
#  0.73649832 0.73425365 0.73732884        nan 0.73887767 0.73117845
#  0.73382716 0.7420202         nan 0.73501684 0.73627385 0.73396184
#  0.73445567        nan 0.73104377 0.73185185 0.73102132 0.7362963
#         nan 0.73717172 0.7369248  0.73667789 0.73586981        nan
#  0.736633   0.73674523 0.73652076 0.73551066        nan 0.73564534
#  0.7356229  0.7356229  0.73510662        nan 0.73382716 0.73378227
#  0.73378227 0.73380471        nan 0.74181818 0.74224467 0.74040404
#  0.73225589        nan 0.67977553 0.68787879 0.6885073  0.68841751
#         nan 0.67102132 0.65699214 0.66368126 0.65257015        nan
#  0.64974186 0.65492705 0.65097643 0.66087542        nan 0.74338945
#  0.74480359 0.74794613 0.73113356        nan 0.71703704 0.72125701
#  0.71391695 0.71874299        nan 0.70291807 0.70675645 0.71537598
#  0.71319865        nan 0.69667789 0.70392817 0.69279461 0.69636364
#         nan 0.74740741 0.75292929 0.75676768 0.75375982        nan
#  0.75391695 0.75445567 0.75975309 0.75106622        nan 0.75068462
#  0.74978676 0.75207632 0.74929293        nan 0.74062851 0.74363636
#  0.74655443 0.74457912        nan 0.74873176 0.75324355 0.75631874
#  0.75750842        nan 0.75849607 0.75479237 0.75789001 0.75824916
#         nan 0.75806958 0.75622896 0.75548822 0.75375982        nan
#  0.74929293 0.75156004 0.751156   0.75129068        nan 0.74837262
#  0.75234568 0.75508418 0.75719416        nan 0.75452301 0.75450056
#  0.75708193 0.75604938        nan 0.75613917 0.75604938 0.75586981
#  0.75503928        nan 0.75310887 0.75310887 0.75301908 0.75315376]
#   warnings.warn(
# GridSearchCV(cv=3,
#              estimator=DecisionTreeClassifier(max_depth=5, max_features=100,
#                                               min_samples_leaf=5,
#                                               min_samples_split=10),
#              param_grid={'max_depth': [1, 3, 5, 7, 10, None],
#                          'max_features': [5, 10, 50, 100, None],
#                          'min_samples_leaf': [1, 5, 10, 20],
#                          'min_samples_split': [1, 5, 10, 20, 40]},
#              verbose=10)

# %%
gs_dtc.best_params_
# Out:
# {'max_depth': None,
#  'max_features': 50,
#  'min_samples_leaf': 5,
#  'min_samples_split': 20}

# %%
dtc = DecisionTreeClassifier(max_depth=5, max_features=100, min_samples_leaf=5, min_samples_split=10)
dtc.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, max_features=100, min_samples_leaf=5,
#                        min_samples_split=10)

# %%
preds = dtc.predict(X_test)

# %%
report_columns = ['functional', 'functional needs repair', 
                  'non functional', 'accuracy', 'macro avg', 
                  'weighted avg']

report_rows = ['precision', 'recall', 
               'f1-score', 'support']

report = pd.DataFrame(classification_report(y_test, preds, output_dict=True), columns=report_columns, index=report_rows)
                      
matrix = pd.DataFrame(confusion_matrix(y_test, preds))

# %%
report
# Out:
#             functional  functional needs repair  non functional  accuracy  \
# precision     0.665686                      0.0        0.860437  0.708822
# recall        0.954687                      0.0        0.494853  0.708822
# f1-score      0.784414                      0.0        0.628337  0.708822
# support    8055.000000                   1064.0     5731.000000  0.708822
#
#               macro avg  weighted avg
# precision      0.508707      0.693149
# recall         0.483180      0.708822
# f1-score       0.470917      0.667977
# support    14850.000000  14850.000000

# %%
matrix
# Out:
#       0  1     2
# 0  7690  0   365
# 1   969  0    95
# 2  2893  2  2836
