# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.metrics import accuracy_score, get_scorer_names, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier, ExtraTreesClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB, CategoricalNB
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from xgboost import XGBClassifier
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from statistics import mode as md
from matplotlib import pyplot as plt
from IPython.display import clear_output, display_html 
from collections import Counter

# %%
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
testing = pd.read_csv("tanzanian_water_wells/X_test.csv")
X = pd.read_csv("tanzanian_water_wells/X_train.csv")
y = pd.read_csv("tanzanian_water_wells/y_train.csv")['status_group'].map({'functional': 2, 'functional needs repair': 0, 'non functional': 1})

# %%
strategy = {1: 20000} #optional strategy
# smote=SMOTE(sampling_strategy=strategy)
smote = SMOTE()

# %%
#Dropping unecessary columns
X = X.drop(['id', 'wpt_name', 'subvillage', 'installer', 'funder', 'scheme_name', 'ward', 'date_recorded', 'recorded_by'], axis=1)
testing = testing.drop(['id', 'wpt_name', 'subvillage', 'installer', 'funder', 'scheme_name', 'ward', 'date_recorded', 'recorded_by'], axis=1)

# Eliminating null values from X_train
X.scheme_management.fillna("None", inplace=True)
X.permit.fillna('Unknown', inplace=True)
X.public_meeting.fillna('Unknown', inplace=True)

# Turning certain dtypes into others
X['permit'] = X['permit'].map({True: 'Yes', False: 'No', 'Unknown': 'Unknown'})
X['gps_height'] = X['gps_height'].astype('float64')
X['population'] = X['population'].astype('float64')
X['construction_year'] = X['construction_year'].astype('int64')
X['region_code'] = X['region_code'].astype('str')
X['district_code'] = X['district_code'].astype('str')

#Defining X_cat
X_cat = X.select_dtypes(exclude=['float64', 'int64'])
X_cat = X_cat.astype('str')
X_cat = pd.get_dummies(X_cat)

#Defining X_numeric
X_numeric = X.select_dtypes(['float64', 'int64'])
scaler = StandardScaler()
scaler.fit(X_numeric)
X_numeric = pd.DataFrame(scaler.transform(X_numeric), columns = X_numeric.columns, index = X_numeric.index)

#Defining X
X = pd.concat([X_numeric, X_cat], axis=1)

#Defining df
df = pd.concat([X, y], axis=1)

#Creating a train-test-split for X and y
X_train, X_test, y_train, y_test = train_test_split(X, y)

#Resampling dataframes for model creation
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)
    
X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)
X_train_resampled = X_train_resampled.reset_index(drop=True)
y_train_resampled = y_train_resampled.reset_index(drop=True)
    
df_resampled = pd.concat([X_train_resampled, y_train_resampled], axis=1)

#Separating concatenated dataframe into each status group
f = df_resampled[df_resampled.status_group == 0].reset_index(drop=True).copy()
nf = df_resampled[df_resampled.status_group == 2].reset_index(drop=True).copy()
fnr = df_resampled[df_resampled.status_group == 1].reset_index(drop=True).copy()

#Shuffling all the records
f = f.sample(frac=1)
nf = nf.sample(frac=1)
fnr = fnr.sample(frac=1)

#Splitting each status group into arrays of approximately 1,000 records
fs = [pd.DataFrame(i) for i in np.array_split(f, len(f)//1000)]
nfs = [pd.DataFrame(i) for i in np.array_split(nf, len(nf)//1000)]
fnrs = [pd.DataFrame(i) for i in np.array_split(fnr, len(fnr)//1000)]

#Creating our individual samples for models to train on
resamples = []
for i in range(len(fnrs)):
    resample = pd.concat([fs[i], nfs[i], fnrs[i]])
    resamples.append(resample)

# %%
estimators = {'Logistic Regression': LogisticRegression(solver='liblinear', fit_intercept=False), 
              'Decision Tree Classifier': DecisionTreeClassifier(), 
              'K-Nearest Neighbors': KNeighborsClassifier(n_neighbors=3), 
              'Bagging Classifier': BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, max_features=50), 
              'Random Forest': RandomForestClassifier(), 
              'XG-Boost': XGBClassifier(), 
              'Adaboost': AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=100, random_state=42), 
              'Gradient Boosted Trees': GradientBoostingClassifier(random_state=42, n_estimators=200, max_features=50), 
              'Extra Randomized Trees': ExtraTreesClassifier(n_estimators=100, random_state=42), 
              'Stacking Classifier': StackingClassifier(
        estimators = [('logistic_regression', LogisticRegression(solver='liblinear', fit_intercept=False)), 
                      ('bagging_classifier', BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, max_features=50))], 
        final_estimator = XGBClassifier())}

# %%
dtc = DecisionTreeClassifier()

param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [1, 2, 5, 10],
    'min_samples_split': [5, 10, 20, 40],
    'min_samples_leaf': [5, 10, 20],
    'splitter': ['best', 'random']
}

gs_tree = GridSearchCV(dtc, param_grid, cv=3, verbose=10)
gs_tree.best_params_

# %%
estimator = DecisionTreeClassifier()

param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [1, 2, 5, 10],
    'min_samples_split': [5, 10, 20, 40],
    'min_samples_leaf': [5, 10, 20],
    'splitter': ['best', 'random']
}

estimator = GridSearchCV(estimator, param_grid, cv=5, verbose=10)
estimator.fit(X_train, y_train)
estimator.best_params_
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# [CV 1/5; 1/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 1/5; 1/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 1/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 2/5; 1/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 1/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 3/5; 1/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 1/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 4/5; 1/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 1/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 5/5; 1/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 2/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 1/5; 2/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 2/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 2/5; 2/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 2/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 3/5; 2/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 2/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 4/5; 2/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 2/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 5/5; 2/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 3/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 1/5; 3/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 3/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 2/5; 3/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 3/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 3/5; 3/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 3/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 4/5; 3/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 3/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 5/5; 3/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 4/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 1/5; 4/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 4/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 2/5; 4/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 4/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 3/5; 4/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 4/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 4/5; 4/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 4/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 5/5; 4/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 5/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 1/5; 5/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 5/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 2/5; 5/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 5/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 3/5; 5/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 5/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 4/5; 5/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 5/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 5/5; 5/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 6/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 1/5; 6/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 6/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 2/5; 6/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 6/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 3/5; 6/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 6/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 4/5; 6/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 6/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 5/5; 6/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 7/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 1/5; 7/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 7/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 2/5; 7/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 7/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 3/5; 7/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 7/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 4/5; 7/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 7/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 5/5; 7/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 8/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 1/5; 8/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 8/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 2/5; 8/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 8/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 3/5; 8/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 8/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 4/5; 8/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 8/192] START criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 5/5; 8/192] END criterion=gini, max_depth=1, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 9/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 1/5; 9/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 9/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 2/5; 9/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 9/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 3/5; 9/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 9/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 4/5; 9/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 9/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 5/5; 9/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 10/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 1/5; 10/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 10/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 2/5; 10/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 10/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 3/5; 10/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 10/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 4/5; 10/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 10/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 5/5; 10/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 11/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 1/5; 11/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 11/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 2/5; 11/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 11/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 3/5; 11/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 11/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 4/5; 11/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 11/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 5/5; 11/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 12/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 1/5; 12/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 12/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 2/5; 12/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 12/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 3/5; 12/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 12/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 4/5; 12/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 12/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 5/5; 12/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 13/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 1/5; 13/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 13/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 2/5; 13/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 13/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 3/5; 13/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 13/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 4/5; 13/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 13/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 5/5; 13/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 14/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 1/5; 14/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 14/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 2/5; 14/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 14/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 3/5; 14/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 14/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 4/5; 14/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 14/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 5/5; 14/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 15/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 1/5; 15/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 15/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 2/5; 15/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 15/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 3/5; 15/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 15/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 4/5; 15/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 15/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 5/5; 15/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 16/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 1/5; 16/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 16/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 2/5; 16/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 16/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 3/5; 16/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 16/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 4/5; 16/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 16/192] START criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 5/5; 16/192] END criterion=gini, max_depth=1, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 17/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 1/5; 17/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 17/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 2/5; 17/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 17/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 3/5; 17/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 17/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 4/5; 17/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 17/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 5/5; 17/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 18/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 1/5; 18/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 18/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 2/5; 18/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 18/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 3/5; 18/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 18/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 4/5; 18/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 18/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 5/5; 18/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 19/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 1/5; 19/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 19/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 2/5; 19/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 19/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 3/5; 19/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 19/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 4/5; 19/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 19/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 5/5; 19/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 20/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 1/5; 20/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 20/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 2/5; 20/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 20/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 3/5; 20/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 20/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 4/5; 20/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 20/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 5/5; 20/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 21/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 1/5; 21/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 21/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 2/5; 21/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 21/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 3/5; 21/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 21/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 4/5; 21/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 21/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 5/5; 21/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 22/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 1/5; 22/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 22/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 2/5; 22/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 22/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 3/5; 22/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 22/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 4/5; 22/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 22/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 5/5; 22/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 23/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 1/5; 23/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.639 total time=   0.1s
# [CV 2/5; 23/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 2/5; 23/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.644 total time=   0.1s
# [CV 3/5; 23/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 3/5; 23/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.643 total time=   0.1s
# [CV 4/5; 23/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 4/5; 23/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.642 total time=   0.1s
# [CV 5/5; 23/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 5/5; 23/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.644 total time=   0.1s
# [CV 1/5; 24/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 1/5; 24/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.639 total time=   0.1s
# [CV 2/5; 24/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 2/5; 24/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.644 total time=   0.1s
# [CV 3/5; 24/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 3/5; 24/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.643 total time=   0.1s
# [CV 4/5; 24/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 4/5; 24/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.642 total time=   0.1s
# [CV 5/5; 24/192] START criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 5/5; 24/192] END criterion=gini, max_depth=1, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.644 total time=   0.1s
# [CV 1/5; 25/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 1/5; 25/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 25/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 2/5; 25/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 25/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 3/5; 25/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 25/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 4/5; 25/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 25/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best
# [CV 5/5; 25/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 26/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 1/5; 26/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 26/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 2/5; 26/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 26/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 3/5; 26/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 26/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 4/5; 26/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 26/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random
# [CV 5/5; 26/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=5, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 27/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 1/5; 27/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 27/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 2/5; 27/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 27/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 3/5; 27/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 27/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 4/5; 27/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 27/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best
# [CV 5/5; 27/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 28/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 1/5; 28/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 28/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 2/5; 28/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 28/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 3/5; 28/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 28/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 4/5; 28/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 28/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random
# [CV 5/5; 28/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=10, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 29/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 1/5; 29/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 29/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 2/5; 29/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 29/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 3/5; 29/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 29/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 4/5; 29/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 29/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best
# [CV 5/5; 29/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 30/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 1/5; 30/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 30/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 2/5; 30/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 30/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 3/5; 30/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 30/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 4/5; 30/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 30/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random
# [CV 5/5; 30/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=20, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 31/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 1/5; 31/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 31/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 2/5; 31/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 31/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 3/5; 31/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 31/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 4/5; 31/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 31/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best
# [CV 5/5; 31/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 32/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 1/5; 32/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 32/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 2/5; 32/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 32/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 3/5; 32/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 32/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 4/5; 32/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 32/192] START criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random
# [CV 5/5; 32/192] END criterion=gini, max_depth=2, min_samples_leaf=5, min_samples_split=40, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 33/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 1/5; 33/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 33/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 2/5; 33/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 33/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 3/5; 33/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 33/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 4/5; 33/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 33/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best
# [CV 5/5; 33/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 34/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 1/5; 34/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 34/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 2/5; 34/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 34/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 3/5; 34/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 34/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 4/5; 34/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 34/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random
# [CV 5/5; 34/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=5, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 35/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 1/5; 35/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 35/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 2/5; 35/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 35/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 3/5; 35/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 35/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 4/5; 35/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 35/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best
# [CV 5/5; 35/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 36/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 1/5; 36/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 36/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 2/5; 36/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 36/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 3/5; 36/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 36/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 4/5; 36/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 36/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random
# [CV 5/5; 36/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 37/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 1/5; 37/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 37/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 2/5; 37/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.695 total time=   0.1s
# [CV 3/5; 37/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 3/5; 37/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.689 total time=   0.1s
# [CV 4/5; 37/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 4/5; 37/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.694 total time=   0.1s
# [CV 5/5; 37/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 5/5; 37/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.699 total time=   0.1s
# [CV 1/5; 38/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 1/5; 38/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.691 total time=   0.1s
# [CV 2/5; 38/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 2/5; 38/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.695 total time=   0.1s
# [CV 3/5; 38/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 3/5; 38/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.689 total time=   0.1s
# [CV 4/5; 38/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 4/5; 38/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.694 total time=   0.1s
# [CV 5/5; 38/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 5/5; 38/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.699 total time=   0.1s
# [CV 1/5; 39/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 1/5; 39/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.691 total time=   0.1s
# [CV 2/5; 39/192] START criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 2/5; 39/192] END criterion=gini, max_depth=2, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.695 total time=   0.1s
# ...
# [CV 5/5; 180/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=10, splitter=random;, score=0.738 total time=   0.3s
# [CV 1/5; 181/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 1/5; 181/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.740 total time=   0.5s
# [CV 2/5; 181/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 2/5; 181/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.739 total time=   0.5s
# [CV 3/5; 181/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 3/5; 181/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.729 total time=   0.5s
# [CV 4/5; 181/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 4/5; 181/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.732 total time=   0.5s
# [CV 5/5; 181/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best
# [CV 5/5; 181/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=best;, score=0.741 total time=   0.5s
# [CV 1/5; 182/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 1/5; 182/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.730 total time=   0.3s
# [CV 2/5; 182/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 2/5; 182/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.736 total time=   0.3s
# [CV 3/5; 182/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 3/5; 182/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.732 total time=   0.3s
# [CV 4/5; 182/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 4/5; 182/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.730 total time=   0.3s
# [CV 5/5; 182/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random
# [CV 5/5; 182/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=20, splitter=random;, score=0.736 total time=   0.3s
# [CV 1/5; 183/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 1/5; 183/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.740 total time=   0.5s
# [CV 2/5; 183/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 2/5; 183/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.740 total time=   0.5s
# [CV 3/5; 183/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 3/5; 183/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.730 total time=   0.5s
# [CV 4/5; 183/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 4/5; 183/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.730 total time=   0.5s
# [CV 5/5; 183/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best
# [CV 5/5; 183/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=best;, score=0.742 total time=   0.5s
# [CV 1/5; 184/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 1/5; 184/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.732 total time=   0.3s
# [CV 2/5; 184/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 2/5; 184/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.734 total time=   0.3s
# [CV 3/5; 184/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 3/5; 184/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.734 total time=   0.3s
# [CV 4/5; 184/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 4/5; 184/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.730 total time=   0.3s
# [CV 5/5; 184/192] START criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random
# [CV 5/5; 184/192] END criterion=entropy, max_depth=10, min_samples_leaf=10, min_samples_split=40, splitter=random;, score=0.738 total time=   0.3s
# [CV 1/5; 185/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 1/5; 185/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.740 total time=   0.5s
# [CV 2/5; 185/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 2/5; 185/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.738 total time=   0.5s
# [CV 3/5; 185/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 3/5; 185/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.728 total time=   0.5s
# [CV 4/5; 185/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 4/5; 185/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.730 total time=   0.4s
# [CV 5/5; 185/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best
# [CV 5/5; 185/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=best;, score=0.739 total time=   0.5s
# [CV 1/5; 186/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 1/5; 186/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.730 total time=   0.3s
# [CV 2/5; 186/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 2/5; 186/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.730 total time=   0.3s
# [CV 3/5; 186/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 3/5; 186/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.730 total time=   0.3s
# [CV 4/5; 186/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 4/5; 186/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.727 total time=   0.3s
# [CV 5/5; 186/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random
# [CV 5/5; 186/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=5, splitter=random;, score=0.738 total time=   0.3s
# [CV 1/5; 187/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 1/5; 187/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.740 total time=   0.5s
# [CV 2/5; 187/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 2/5; 187/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.738 total time=   0.4s
# [CV 3/5; 187/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 3/5; 187/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.728 total time=   0.5s
# [CV 4/5; 187/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 4/5; 187/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.730 total time=   0.4s
# [CV 5/5; 187/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best
# [CV 5/5; 187/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=best;, score=0.739 total time=   0.4s
# [CV 1/5; 188/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 1/5; 188/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.729 total time=   0.3s
# [CV 2/5; 188/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 2/5; 188/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.731 total time=   0.3s
# [CV 3/5; 188/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 3/5; 188/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.729 total time=   0.3s
# [CV 4/5; 188/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 4/5; 188/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.725 total time=   0.3s
# [CV 5/5; 188/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random
# [CV 5/5; 188/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=10, splitter=random;, score=0.737 total time=   0.3s
# [CV 1/5; 189/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 1/5; 189/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.740 total time=   0.4s
# [CV 2/5; 189/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 2/5; 189/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.738 total time=   0.5s
# [CV 3/5; 189/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 3/5; 189/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.728 total time=   0.5s
# [CV 4/5; 189/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 4/5; 189/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.730 total time=   0.4s
# [CV 5/5; 189/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best
# [CV 5/5; 189/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=best;, score=0.739 total time=   0.5s
# [CV 1/5; 190/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 1/5; 190/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.732 total time=   0.3s
# [CV 2/5; 190/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 2/5; 190/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.732 total time=   0.3s
# [CV 3/5; 190/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 3/5; 190/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.730 total time=   0.3s
# [CV 4/5; 190/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 4/5; 190/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.726 total time=   0.3s
# [CV 5/5; 190/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random
# [CV 5/5; 190/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=20, splitter=random;, score=0.736 total time=   0.3s
# [CV 1/5; 191/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 1/5; 191/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.740 total time=   0.5s
# [CV 2/5; 191/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 2/5; 191/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.739 total time=   0.4s
# [CV 3/5; 191/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 3/5; 191/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.728 total time=   0.5s
# [CV 4/5; 191/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 4/5; 191/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.730 total time=   0.5s
# [CV 5/5; 191/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best
# [CV 5/5; 191/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=best;, score=0.739 total time=   0.5s
# [CV 1/5; 192/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 1/5; 192/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.730 total time=   0.3s
# [CV 2/5; 192/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 2/5; 192/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.730 total time=   0.3s
# [CV 3/5; 192/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 3/5; 192/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.731 total time=   0.3s
# [CV 4/5; 192/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 4/5; 192/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.727 total time=   0.3s
# [CV 5/5; 192/192] START criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random
# [CV 5/5; 192/192] END criterion=entropy, max_depth=10, min_samples_leaf=20, min_samples_split=40, splitter=random;, score=0.736 total time=   0.3s
# {'criterion': 'gini',
#  'max_depth': 10,
#  'min_samples_leaf': 5,
#  'min_samples_split': 20,
#  'splitter': 'best'}

# %%
estimator.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 10,
#  'min_samples_leaf': 5,
#  'min_samples_split': 20,
#  'splitter': 'best'}

# %%
estimator = DecisionTreeClassifier()

# %%
estimator.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = estimator.predict(X_test)

# %%
pd.DataFrame(confusion_matrix(y_test, predictions))
# Out:
#      0     1     2
# 0  404   181   517
# 1  204  4331  1186
# 2  454  1192  6381

# %%
pd.DataFrame(classification_report(y_test, predictions, output_dict=True))
# Out:
#                      0            1            2  accuracy     macro avg  \
# precision     0.380414     0.759292     0.789337  0.748552      0.643014
# recall        0.366606     0.757035     0.794942  0.748552      0.639528
# f1-score      0.373383     0.758162     0.792130  0.748552      0.641225
# support    1102.000000  5721.000000  8027.000000  0.748552  14850.000000
#
#            weighted avg
# precision      0.747416
# recall         0.748552
# f1-score       0.747969
# support    14850.000000

# %%
estimator = KNeighborsClassifier()

param_grid = {
    'metric': ['euclidean', 'minkowski', 'manhattan'],
    'n_neighbors': [3,4,5,6,7,8,9,10],
    'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
    
}

estimator = GridSearchCV(estimator, param_grid, cv=5, verbose=10)
estimator.fit(X_train, y_train)
estimator.best_params_
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5; 1/96] START algorithm=auto, metric=euclidean, n_neighbors=3............
# [CV 1/5; 1/96] END algorithm=auto, metric=euclidean, n_neighbors=3;, score=0.768 total time=   1.9s
# [CV 2/5; 1/96] START algorithm=auto, metric=euclidean, n_neighbors=3............
# [CV 2/5; 1/96] END algorithm=auto, metric=euclidean, n_neighbors=3;, score=0.765 total time=   1.9s
# [CV 3/5; 1/96] START algorithm=auto, metric=euclidean, n_neighbors=3............
# [CV 3/5; 1/96] END algorithm=auto, metric=euclidean, n_neighbors=3;, score=0.763 total time=   1.9s
# [CV 4/5; 1/96] START algorithm=auto, metric=euclidean, n_neighbors=3............
# [CV 4/5; 1/96] END algorithm=auto, metric=euclidean, n_neighbors=3;, score=0.754 total time=   1.9s
# [CV 5/5; 1/96] START algorithm=auto, metric=euclidean, n_neighbors=3............
# [CV 5/5; 1/96] END algorithm=auto, metric=euclidean, n_neighbors=3;, score=0.762 total time=   1.9s
# [CV 1/5; 2/96] START algorithm=auto, metric=euclidean, n_neighbors=4............
# [CV 1/5; 2/96] END algorithm=auto, metric=euclidean, n_neighbors=4;, score=0.758 total time=   1.9s
# [CV 2/5; 2/96] START algorithm=auto, metric=euclidean, n_neighbors=4............
# [CV 2/5; 2/96] END algorithm=auto, metric=euclidean, n_neighbors=4;, score=0.757 total time=   2.0s
# [CV 3/5; 2/96] START algorithm=auto, metric=euclidean, n_neighbors=4............
# [CV 3/5; 2/96] END algorithm=auto, metric=euclidean, n_neighbors=4;, score=0.759 total time=   1.9s
# [CV 4/5; 2/96] START algorithm=auto, metric=euclidean, n_neighbors=4............
# [CV 4/5; 2/96] END algorithm=auto, metric=euclidean, n_neighbors=4;, score=0.744 total time=   2.0s
# [CV 5/5; 2/96] START algorithm=auto, metric=euclidean, n_neighbors=4............
# [CV 5/5; 2/96] END algorithm=auto, metric=euclidean, n_neighbors=4;, score=0.760 total time=   2.9s
# [CV 1/5; 3/96] START algorithm=auto, metric=euclidean, n_neighbors=5............
# [CV 1/5; 3/96] END algorithm=auto, metric=euclidean, n_neighbors=5;, score=0.767 total time=   2.5s
# [CV 2/5; 3/96] START algorithm=auto, metric=euclidean, n_neighbors=5............
# [CV 2/5; 3/96] END algorithm=auto, metric=euclidean, n_neighbors=5;, score=0.768 total time=   2.0s
# [CV 3/5; 3/96] START algorithm=auto, metric=euclidean, n_neighbors=5............
# [CV 3/5; 3/96] END algorithm=auto, metric=euclidean, n_neighbors=5;, score=0.771 total time=   2.0s
# [CV 4/5; 3/96] START algorithm=auto, metric=euclidean, n_neighbors=5............
# [CV 4/5; 3/96] END algorithm=auto, metric=euclidean, n_neighbors=5;, score=0.757 total time=   1.9s
# [CV 5/5; 3/96] START algorithm=auto, metric=euclidean, n_neighbors=5............
# [CV 5/5; 3/96] END algorithm=auto, metric=euclidean, n_neighbors=5;, score=0.770 total time=   2.0s
# [CV 1/5; 4/96] START algorithm=auto, metric=euclidean, n_neighbors=6............
# [CV 1/5; 4/96] END algorithm=auto, metric=euclidean, n_neighbors=6;, score=0.766 total time=   2.1s
# [CV 2/5; 4/96] START algorithm=auto, metric=euclidean, n_neighbors=6............
# [CV 2/5; 4/96] END algorithm=auto, metric=euclidean, n_neighbors=6;, score=0.761 total time=   2.0s
# [CV 3/5; 4/96] START algorithm=auto, metric=euclidean, n_neighbors=6............
# [CV 3/5; 4/96] END algorithm=auto, metric=euclidean, n_neighbors=6;, score=0.770 total time=   2.1s
# [CV 4/5; 4/96] START algorithm=auto, metric=euclidean, n_neighbors=6............
# [CV 4/5; 4/96] END algorithm=auto, metric=euclidean, n_neighbors=6;, score=0.752 total time=   2.1s
# [CV 5/5; 4/96] START algorithm=auto, metric=euclidean, n_neighbors=6............
# [CV 5/5; 4/96] END algorithm=auto, metric=euclidean, n_neighbors=6;, score=0.769 total time=   2.2s
# [CV 1/5; 5/96] START algorithm=auto, metric=euclidean, n_neighbors=7............
# [CV 1/5; 5/96] END algorithm=auto, metric=euclidean, n_neighbors=7;, score=0.772 total time=   2.6s
# [CV 2/5; 5/96] START algorithm=auto, metric=euclidean, n_neighbors=7............
# [CV 2/5; 5/96] END algorithm=auto, metric=euclidean, n_neighbors=7;, score=0.768 total time=   2.4s
# [CV 3/5; 5/96] START algorithm=auto, metric=euclidean, n_neighbors=7............
# [CV 3/5; 5/96] END algorithm=auto, metric=euclidean, n_neighbors=7;, score=0.774 total time=   2.1s
# [CV 4/5; 5/96] START algorithm=auto, metric=euclidean, n_neighbors=7............
# [CV 4/5; 5/96] END algorithm=auto, metric=euclidean, n_neighbors=7;, score=0.758 total time=   2.1s
# [CV 5/5; 5/96] START algorithm=auto, metric=euclidean, n_neighbors=7............
# [CV 5/5; 5/96] END algorithm=auto, metric=euclidean, n_neighbors=7;, score=0.772 total time=   2.1s
# [CV 1/5; 6/96] START algorithm=auto, metric=euclidean, n_neighbors=8............
# [CV 1/5; 6/96] END algorithm=auto, metric=euclidean, n_neighbors=8;, score=0.767 total time=   2.1s
# [CV 2/5; 6/96] START algorithm=auto, metric=euclidean, n_neighbors=8............
# [CV 2/5; 6/96] END algorithm=auto, metric=euclidean, n_neighbors=8;, score=0.762 total time=   2.1s
# [CV 3/5; 6/96] START algorithm=auto, metric=euclidean, n_neighbors=8............
# [CV 3/5; 6/96] END algorithm=auto, metric=euclidean, n_neighbors=8;, score=0.772 total time=   2.4s
# [CV 4/5; 6/96] START algorithm=auto, metric=euclidean, n_neighbors=8............
# [CV 4/5; 6/96] END algorithm=auto, metric=euclidean, n_neighbors=8;, score=0.756 total time=   2.2s
# [CV 5/5; 6/96] START algorithm=auto, metric=euclidean, n_neighbors=8............
# [CV 5/5; 6/96] END algorithm=auto, metric=euclidean, n_neighbors=8;, score=0.772 total time=   2.0s
# [CV 1/5; 7/96] START algorithm=auto, metric=euclidean, n_neighbors=9............
# [CV 1/5; 7/96] END algorithm=auto, metric=euclidean, n_neighbors=9;, score=0.771 total time=   2.0s
# [CV 2/5; 7/96] START algorithm=auto, metric=euclidean, n_neighbors=9............
# [CV 2/5; 7/96] END algorithm=auto, metric=euclidean, n_neighbors=9;, score=0.760 total time=   2.4s
# [CV 3/5; 7/96] START algorithm=auto, metric=euclidean, n_neighbors=9............
# [CV 3/5; 7/96] END algorithm=auto, metric=euclidean, n_neighbors=9;, score=0.775 total time=   2.3s
# [CV 4/5; 7/96] START algorithm=auto, metric=euclidean, n_neighbors=9............
# [CV 4/5; 7/96] END algorithm=auto, metric=euclidean, n_neighbors=9;, score=0.759 total time=   2.2s
# [CV 5/5; 7/96] START algorithm=auto, metric=euclidean, n_neighbors=9............
# [CV 5/5; 7/96] END algorithm=auto, metric=euclidean, n_neighbors=9;, score=0.771 total time=   2.4s
# [CV 1/5; 8/96] START algorithm=auto, metric=euclidean, n_neighbors=10...........
# [CV 1/5; 8/96] END algorithm=auto, metric=euclidean, n_neighbors=10;, score=0.769 total time=   3.7s
# [CV 2/5; 8/96] START algorithm=auto, metric=euclidean, n_neighbors=10...........
# [CV 2/5; 8/96] END algorithm=auto, metric=euclidean, n_neighbors=10;, score=0.765 total time=   2.3s
# [CV 3/5; 8/96] START algorithm=auto, metric=euclidean, n_neighbors=10...........
# [CV 3/5; 8/96] END algorithm=auto, metric=euclidean, n_neighbors=10;, score=0.774 total time=   3.0s
# [CV 4/5; 8/96] START algorithm=auto, metric=euclidean, n_neighbors=10...........
# [CV 4/5; 8/96] END algorithm=auto, metric=euclidean, n_neighbors=10;, score=0.757 total time=   3.1s
# [CV 5/5; 8/96] START algorithm=auto, metric=euclidean, n_neighbors=10...........
# [CV 5/5; 8/96] END algorithm=auto, metric=euclidean, n_neighbors=10;, score=0.769 total time=   3.2s
# [CV 1/5; 9/96] START algorithm=auto, metric=minkowski, n_neighbors=3............
# [CV 1/5; 9/96] END algorithm=auto, metric=minkowski, n_neighbors=3;, score=0.768 total time=   3.3s
# [CV 2/5; 9/96] START algorithm=auto, metric=minkowski, n_neighbors=3............
# [CV 2/5; 9/96] END algorithm=auto, metric=minkowski, n_neighbors=3;, score=0.765 total time=   2.8s
# [CV 3/5; 9/96] START algorithm=auto, metric=minkowski, n_neighbors=3............
# [CV 3/5; 9/96] END algorithm=auto, metric=minkowski, n_neighbors=3;, score=0.763 total time=   2.3s
# [CV 4/5; 9/96] START algorithm=auto, metric=minkowski, n_neighbors=3............
# [CV 4/5; 9/96] END algorithm=auto, metric=minkowski, n_neighbors=3;, score=0.754 total time=   2.2s
# [CV 5/5; 9/96] START algorithm=auto, metric=minkowski, n_neighbors=3............
# [CV 5/5; 9/96] END algorithm=auto, metric=minkowski, n_neighbors=3;, score=0.762 total time=   2.7s
# [CV 1/5; 10/96] START algorithm=auto, metric=minkowski, n_neighbors=4...........
# [CV 1/5; 10/96] END algorithm=auto, metric=minkowski, n_neighbors=4;, score=0.758 total time=   2.5s
# [CV 2/5; 10/96] START algorithm=auto, metric=minkowski, n_neighbors=4...........
# [CV 2/5; 10/96] END algorithm=auto, metric=minkowski, n_neighbors=4;, score=0.757 total time=   2.5s
# [CV 3/5; 10/96] START algorithm=auto, metric=minkowski, n_neighbors=4...........
# [CV 3/5; 10/96] END algorithm=auto, metric=minkowski, n_neighbors=4;, score=0.759 total time=   3.9s
# [CV 4/5; 10/96] START algorithm=auto, metric=minkowski, n_neighbors=4...........
# [CV 4/5; 10/96] END algorithm=auto, metric=minkowski, n_neighbors=4;, score=0.744 total time=   4.5s
# [CV 5/5; 10/96] START algorithm=auto, metric=minkowski, n_neighbors=4...........
# [CV 5/5; 10/96] END algorithm=auto, metric=minkowski, n_neighbors=4;, score=0.760 total time=   2.6s
# [CV 1/5; 11/96] START algorithm=auto, metric=minkowski, n_neighbors=5...........
# [CV 1/5; 11/96] END algorithm=auto, metric=minkowski, n_neighbors=5;, score=0.767 total time=   2.4s
# [CV 2/5; 11/96] START algorithm=auto, metric=minkowski, n_neighbors=5...........
# [CV 2/5; 11/96] END algorithm=auto, metric=minkowski, n_neighbors=5;, score=0.768 total time=   2.3s
# [CV 3/5; 11/96] START algorithm=auto, metric=minkowski, n_neighbors=5...........
# [CV 3/5; 11/96] END algorithm=auto, metric=minkowski, n_neighbors=5;, score=0.771 total time=   2.3s
# [CV 4/5; 11/96] START algorithm=auto, metric=minkowski, n_neighbors=5...........
# [CV 4/5; 11/96] END algorithm=auto, metric=minkowski, n_neighbors=5;, score=0.757 total time=   2.3s
# [CV 5/5; 11/96] START algorithm=auto, metric=minkowski, n_neighbors=5...........
# [CV 5/5; 11/96] END algorithm=auto, metric=minkowski, n_neighbors=5;, score=0.770 total time=   2.3s
# [CV 1/5; 12/96] START algorithm=auto, metric=minkowski, n_neighbors=6...........
# [CV 1/5; 12/96] END algorithm=auto, metric=minkowski, n_neighbors=6;, score=0.766 total time=   2.4s
# [CV 2/5; 12/96] START algorithm=auto, metric=minkowski, n_neighbors=6...........
# [CV 2/5; 12/96] END algorithm=auto, metric=minkowski, n_neighbors=6;, score=0.761 total time=   3.3s
# [CV 3/5; 12/96] START algorithm=auto, metric=minkowski, n_neighbors=6...........
# [CV 3/5; 12/96] END algorithm=auto, metric=minkowski, n_neighbors=6;, score=0.770 total time=   3.1s
# [CV 4/5; 12/96] START algorithm=auto, metric=minkowski, n_neighbors=6...........
# [CV 4/5; 12/96] END algorithm=auto, metric=minkowski, n_neighbors=6;, score=0.752 total time=   2.7s
# [CV 5/5; 12/96] START algorithm=auto, metric=minkowski, n_neighbors=6...........
# [CV 5/5; 12/96] END algorithm=auto, metric=minkowski, n_neighbors=6;, score=0.769 total time=   3.4s
# [CV 1/5; 13/96] START algorithm=auto, metric=minkowski, n_neighbors=7...........
# [CV 1/5; 13/96] END algorithm=auto, metric=minkowski, n_neighbors=7;, score=0.772 total time=   3.2s
# [CV 2/5; 13/96] START algorithm=auto, metric=minkowski, n_neighbors=7...........
# [CV 2/5; 13/96] END algorithm=auto, metric=minkowski, n_neighbors=7;, score=0.768 total time=   2.9s
# [CV 3/5; 13/96] START algorithm=auto, metric=minkowski, n_neighbors=7...........
# [CV 3/5; 13/96] END algorithm=auto, metric=minkowski, n_neighbors=7;, score=0.774 total time=   2.7s
# [CV 4/5; 13/96] START algorithm=auto, metric=minkowski, n_neighbors=7...........
# [CV 4/5; 13/96] END algorithm=auto, metric=minkowski, n_neighbors=7;, score=0.758 total time=   2.8s
# [CV 5/5; 13/96] START algorithm=auto, metric=minkowski, n_neighbors=7...........
# [CV 5/5; 13/96] END algorithm=auto, metric=minkowski, n_neighbors=7;, score=0.772 total time=   2.3s
# [CV 1/5; 14/96] START algorithm=auto, metric=minkowski, n_neighbors=8...........
# [CV 1/5; 14/96] END algorithm=auto, metric=minkowski, n_neighbors=8;, score=0.767 total time=   2.4s
# [CV 2/5; 14/96] START algorithm=auto, metric=minkowski, n_neighbors=8...........
# [CV 2/5; 14/96] END algorithm=auto, metric=minkowski, n_neighbors=8;, score=0.762 total time=   2.7s
# [CV 3/5; 14/96] START algorithm=auto, metric=minkowski, n_neighbors=8...........
# [CV 3/5; 14/96] END algorithm=auto, metric=minkowski, n_neighbors=8;, score=0.772 total time=   2.7s
# [CV 4/5; 14/96] START algorithm=auto, metric=minkowski, n_neighbors=8...........
# [CV 4/5; 14/96] END algorithm=auto, metric=minkowski, n_neighbors=8;, score=0.756 total time=   2.6s
# [CV 5/5; 14/96] START algorithm=auto, metric=minkowski, n_neighbors=8...........
# [CV 5/5; 14/96] END algorithm=auto, metric=minkowski, n_neighbors=8;, score=0.772 total time=   2.8s
# [CV 1/5; 15/96] START algorithm=auto, metric=minkowski, n_neighbors=9...........
# [CV 1/5; 15/96] END algorithm=auto, metric=minkowski, n_neighbors=9;, score=0.771 total time=   2.9s
# [CV 2/5; 15/96] START algorithm=auto, metric=minkowski, n_neighbors=9...........
# [CV 2/5; 15/96] END algorithm=auto, metric=minkowski, n_neighbors=9;, score=0.760 total time=   3.0s
# [CV 3/5; 15/96] START algorithm=auto, metric=minkowski, n_neighbors=9...........
# [CV 3/5; 15/96] END algorithm=auto, metric=minkowski, n_neighbors=9;, score=0.775 total time=   3.1s
# [CV 4/5; 15/96] START algorithm=auto, metric=minkowski, n_neighbors=9...........
# [CV 4/5; 15/96] END algorithm=auto, metric=minkowski, n_neighbors=9;, score=0.759 total time=   2.6s
# [CV 5/5; 15/96] START algorithm=auto, metric=minkowski, n_neighbors=9...........
# [CV 5/5; 15/96] END algorithm=auto, metric=minkowski, n_neighbors=9;, score=0.771 total time=   3.6s
# [CV 1/5; 16/96] START algorithm=auto, metric=minkowski, n_neighbors=10..........
# [CV 1/5; 16/96] END algorithm=auto, metric=minkowski, n_neighbors=10;, score=0.769 total time=   3.9s
# [CV 2/5; 16/96] START algorithm=auto, metric=minkowski, n_neighbors=10..........
# [CV 2/5; 16/96] END algorithm=auto, metric=minkowski, n_neighbors=10;, score=0.765 total time=   3.2s
# [CV 3/5; 16/96] START algorithm=auto, metric=minkowski, n_neighbors=10..........
# [CV 3/5; 16/96] END algorithm=auto, metric=minkowski, n_neighbors=10;, score=0.774 total time=   3.0s
# [CV 4/5; 16/96] START algorithm=auto, metric=minkowski, n_neighbors=10..........
# [CV 4/5; 16/96] END algorithm=auto, metric=minkowski, n_neighbors=10;, score=0.757 total time=   2.6s
# [CV 5/5; 16/96] START algorithm=auto, metric=minkowski, n_neighbors=10..........
# [CV 5/5; 16/96] END algorithm=auto, metric=minkowski, n_neighbors=10;, score=0.769 total time=   2.7s
# [CV 1/5; 17/96] START algorithm=auto, metric=manhattan, n_neighbors=3...........
# [CV 1/5; 17/96] END algorithm=auto, metric=manhattan, n_neighbors=3;, score=0.769 total time=  21.7s
# [CV 2/5; 17/96] START algorithm=auto, metric=manhattan, n_neighbors=3...........
# [CV 2/5; 17/96] END algorithm=auto, metric=manhattan, n_neighbors=3;, score=0.767 total time=  21.5s
# [CV 3/5; 17/96] START algorithm=auto, metric=manhattan, n_neighbors=3...........
# [CV 3/5; 17/96] END algorithm=auto, metric=manhattan, n_neighbors=3;, score=0.769 total time=  21.4s
# [CV 4/5; 17/96] START algorithm=auto, metric=manhattan, n_neighbors=3...........
# [CV 4/5; 17/96] END algorithm=auto, metric=manhattan, n_neighbors=3;, score=0.755 total time=  21.6s
# [CV 5/5; 17/96] START algorithm=auto, metric=manhattan, n_neighbors=3...........
# [CV 5/5; 17/96] END algorithm=auto, metric=manhattan, n_neighbors=3;, score=0.766 total time=  23.1s
# [CV 1/5; 18/96] START algorithm=auto, metric=manhattan, n_neighbors=4...........
# [CV 1/5; 18/96] END algorithm=auto, metric=manhattan, n_neighbors=4;, score=0.763 total time=  20.6s
# [CV 2/5; 18/96] START algorithm=auto, metric=manhattan, n_neighbors=4...........
# [CV 2/5; 18/96] END algorithm=auto, metric=manhattan, n_neighbors=4;, score=0.758 total time=  20.3s
# [CV 3/5; 18/96] START algorithm=auto, metric=manhattan, n_neighbors=4...........
# [CV 3/5; 18/96] END algorithm=auto, metric=manhattan, n_neighbors=4;, score=0.765 total time=  19.5s
# [CV 4/5; 18/96] START algorithm=auto, metric=manhattan, n_neighbors=4...........
# [CV 4/5; 18/96] END algorithm=auto, metric=manhattan, n_neighbors=4;, score=0.748 total time=  19.7s
# [CV 5/5; 18/96] START algorithm=auto, metric=manhattan, n_neighbors=4...........
# [CV 5/5; 18/96] END algorithm=auto, metric=manhattan, n_neighbors=4;, score=0.763 total time=  18.9s
# [CV 1/5; 19/96] START algorithm=auto, metric=manhattan, n_neighbors=5...........
# [CV 1/5; 19/96] END algorithm=auto, metric=manhattan, n_neighbors=5;, score=0.770 total time=  18.4s
# [CV 2/5; 19/96] START algorithm=auto, metric=manhattan, n_neighbors=5...........
# [CV 2/5; 19/96] END algorithm=auto, metric=manhattan, n_neighbors=5;, score=0.768 total time=  19.0s
# [CV 3/5; 19/96] START algorithm=auto, metric=manhattan, n_neighbors=5...........
# [CV 3/5; 19/96] END algorithm=auto, metric=manhattan, n_neighbors=5;, score=0.773 total time=  20.7s
# [CV 4/5; 19/96] START algorithm=auto, metric=manhattan, n_neighbors=5...........
# [CV 4/5; 19/96] END algorithm=auto, metric=manhattan, n_neighbors=5;, score=0.760 total time=  19.7s
# [CV 5/5; 19/96] START algorithm=auto, metric=manhattan, n_neighbors=5...........
# [CV 5/5; 19/96] END algorithm=auto, metric=manhattan, n_neighbors=5;, score=0.771 total time=  19.1s
# [CV 1/5; 20/96] START algorithm=auto, metric=manhattan, n_neighbors=6...........
# [CV 1/5; 20/96] END algorithm=auto, metric=manhattan, n_neighbors=6;, score=0.770 total time=  19.2s
# [CV 2/5; 20/96] START algorithm=auto, metric=manhattan, n_neighbors=6...........
# [CV 2/5; 20/96] END algorithm=auto, metric=manhattan, n_neighbors=6;, score=0.762 total time=  18.9s
# [CV 3/5; 20/96] START algorithm=auto, metric=manhattan, n_neighbors=6...........
# [CV 3/5; 20/96] END algorithm=auto, metric=manhattan, n_neighbors=6;, score=0.772 total time=  18.7s
# [CV 4/5; 20/96] START algorithm=auto, metric=manhattan, n_neighbors=6...........
# [CV 4/5; 20/96] END algorithm=auto, metric=manhattan, n_neighbors=6;, score=0.758 total time=  18.8s
# [CV 5/5; 20/96] START algorithm=auto, metric=manhattan, n_neighbors=6...........
# [CV 5/5; 20/96] END algorithm=auto, metric=manhattan, n_neighbors=6;, score=0.772 total time=  18.8s
# [CV 1/5; 21/96] START algorithm=auto, metric=manhattan, n_neighbors=7...........
# [CV 1/5; 21/96] END algorithm=auto, metric=manhattan, n_neighbors=7;, score=0.774 total time=  22.2s
# [CV 2/5; 21/96] START algorithm=auto, metric=manhattan, n_neighbors=7...........
# [CV 2/5; 21/96] END algorithm=auto, metric=manhattan, n_neighbors=7;, score=0.772 total time=  19.5s
# [CV 3/5; 21/96] START algorithm=auto, metric=manhattan, n_neighbors=7...........
# [CV 3/5; 21/96] END algorithm=auto, metric=manhattan, n_neighbors=7;, score=0.778 total time=  19.1s
# [CV 4/5; 21/96] START algorithm=auto, metric=manhattan, n_neighbors=7...........
# [CV 4/5; 21/96] END algorithm=auto, metric=manhattan, n_neighbors=7;, score=0.759 total time=  19.4s
# [CV 5/5; 21/96] START algorithm=auto, metric=manhattan, n_neighbors=7...........
# [CV 5/5; 21/96] END algorithm=auto, metric=manhattan, n_neighbors=7;, score=0.776 total time=  19.4s
# [CV 1/5; 22/96] START algorithm=auto, metric=manhattan, n_neighbors=8...........
# [CV 1/5; 22/96] END algorithm=auto, metric=manhattan, n_neighbors=8;, score=0.770 total time=  19.0s
# [CV 2/5; 22/96] START algorithm=auto, metric=manhattan, n_neighbors=8...........
# [CV 2/5; 22/96] END algorithm=auto, metric=manhattan, n_neighbors=8;, score=0.764 total time=  18.9s
# [CV 3/5; 22/96] START algorithm=auto, metric=manhattan, n_neighbors=8...........
# [CV 3/5; 22/96] END algorithm=auto, metric=manhattan, n_neighbors=8;, score=0.775 total time=  20.1s
# [CV 4/5; 22/96] START algorithm=auto, metric=manhattan, n_neighbors=8...........
# [CV 4/5; 22/96] END algorithm=auto, metric=manhattan, n_neighbors=8;, score=0.757 total time=  20.4s
# [CV 5/5; 22/96] START algorithm=auto, metric=manhattan, n_neighbors=8...........
# [CV 5/5; 22/96] END algorithm=auto, metric=manhattan, n_neighbors=8;, score=0.773 total time=  19.0s
# [CV 1/5; 23/96] START algorithm=auto, metric=manhattan, n_neighbors=9...........
# [CV 1/5; 23/96] END algorithm=auto, metric=manhattan, n_neighbors=9;, score=0.773 total time=  19.7s
# [CV 2/5; 23/96] START algorithm=auto, metric=manhattan, n_neighbors=9...........
# [CV 2/5; 23/96] END algorithm=auto, metric=manhattan, n_neighbors=9;, score=0.766 total time=  19.0s
# [CV 3/5; 23/96] START algorithm=auto, metric=manhattan, n_neighbors=9...........
# [CV 3/5; 23/96] END algorithm=auto, metric=manhattan, n_neighbors=9;, score=0.779 total time=  21.6s
# [CV 4/5; 23/96] START algorithm=auto, metric=manhattan, n_neighbors=9...........
# [CV 4/5; 23/96] END algorithm=auto, metric=manhattan, n_neighbors=9;, score=0.762 total time=  22.4s
# [CV 5/5; 23/96] START algorithm=auto, metric=manhattan, n_neighbors=9...........
# [CV 5/5; 23/96] END algorithm=auto, metric=manhattan, n_neighbors=9;, score=0.773 total time=  23.1s
# [CV 1/5; 24/96] START algorithm=auto, metric=manhattan, n_neighbors=10..........
# [CV 1/5; 24/96] END algorithm=auto, metric=manhattan, n_neighbors=10;, score=0.770 total time=  24.2s
# [CV 2/5; 24/96] START algorithm=auto, metric=manhattan, n_neighbors=10..........
# [CV 2/5; 24/96] END algorithm=auto, metric=manhattan, n_neighbors=10;, score=0.765 total time=  19.3s
# [CV 3/5; 24/96] START algorithm=auto, metric=manhattan, n_neighbors=10..........
# [CV 3/5; 24/96] END algorithm=auto, metric=manhattan, n_neighbors=10;, score=0.776 total time=  23.7s
# [CV 4/5; 24/96] START algorithm=auto, metric=manhattan, n_neighbors=10..........
# [CV 4/5; 24/96] END algorithm=auto, metric=manhattan, n_neighbors=10;, score=0.759 total time=  25.7s
# [CV 5/5; 24/96] START algorithm=auto, metric=manhattan, n_neighbors=10..........
