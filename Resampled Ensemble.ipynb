# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from sklearn.model_selection import train_test_split, cross_val_score, StratifiedKFold
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso
from sklearn.preprocessing import MinMaxScaler, StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.metrics import accuracy_score, get_scorer_names, confusion_matrix, classification_report
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, VotingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier, ExtraTreesClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB, CategoricalNB
from sklearn.feature_selection import SelectKBest, chi2, mutual_info_classif
from xgboost import XGBClassifier
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from statistics import mode as md
from matplotlib import pyplot as plt
from IPython.display import clear_output
from collections import Counter

# %%
testing = pd.read_csv("tanzanian_water_wells/X_test.csv")
X = pd.read_csv("tanzanian_water_wells/X_train.csv")
y = pd.read_csv("tanzanian_water_wells/y_train.csv")['status_group'].map({'functional': 0, 'functional needs repair': 1, 'non functional': 2})

# %%
X = X.drop(['id', 'wpt_name', 'subvillage', 'installer', 'funder', 'scheme_name', 'ward', 'date_recorded', 'recorded_by'], axis=1)
testing = testing.drop(['id', 'wpt_name', 'subvillage', 'installer', 'funder', 'scheme_name', 'ward', 'date_recorded', 'recorded_by'], axis=1)

# %%
# Eliminating null values from X_train
X.scheme_management.fillna("None", inplace=True)
X.permit.fillna('Unknown', inplace=True)
X.public_meeting.fillna('Unknown', inplace=True)

# %%
# X['public_meeting'] = X['public_meeting'].map({True: 'Yes', False: 'No', 'Unknown': 'Unknown'})
X['permit'] = X['permit'].map({True: 'Yes', False: 'No', 'Unknown': 'Unknown'})
X['gps_height'] = X['gps_height'].astype('float64')
# X['district_code'] = X['district_code'].astype('float64')
X['population'] = X['population'].astype('float64')
X['construction_year'] = X['construction_year'].astype('int64')
X['region_code'] = X['region_code'].astype('str')
X['district_code'] = X['district_code'].astype('str')

X_cat = X.select_dtypes(exclude=['float64', 'int64'])
X_cat = X_cat.astype('str')
X_numeric = X.select_dtypes(['float64', 'int64'])

# %%
X_cat = X_cat.drop(['quantity', 'waterpoint_type_group', 'extraction_type_group', 
                    'region', 'extraction_type', 'payment_type', 'source_type', 
                    'management_group', 'water_quality', 'source_class', 
                    'region_code', 'district_code'], axis=1)

testing = testing.drop(['quantity', 'waterpoint_type_group', 'extraction_type_group', 
                    'region', 'extraction_type', 'payment_type', 'source_type', 
                    'management_group', 'water_quality', 'source_class', 
                    'region_code', 'district_code'], axis=1)

# %%
X_cat = pd.get_dummies(X_cat)

# %%
scaler = StandardScaler()
scaler.fit(X_numeric)
X_numeric = pd.DataFrame(scaler.transform(X_numeric), columns = X_numeric.columns, index = X_numeric.index)

# %%
df = pd.concat([X_numeric, X_cat, y], axis=1)

# %%
X = pd.concat([X_numeric, X_cat], axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
df_train, df_test = train_test_split(df)

# %%
df_train.reset_index(drop=True, inplace=True)
df_test.reset_index(drop=True, inplace=True)

# %%
df_train
# Out:
#        amount_tsh  gps_height  longitude  latitude  num_private  population  \
# 0        -0.10597   -0.964200  -5.188895  1.936878    -0.038749   -0.381587
# 1        -0.10597    1.106177   0.460238  0.862463    -0.038749   -0.379466
# 2        -0.10597   -0.964200  -0.482288  1.433735    -0.038749   -0.381587
# 3        -0.10597   -0.964200  -0.039499 -1.284573    -0.038749   -0.381587
# 4        -0.10597   -0.964200  -0.366471  1.315739    -0.038749   -0.381587
# ...           ...         ...        ...       ...          ...         ...
# 44545    -0.10597    0.852249   0.038591  1.268555    -0.038749    0.891006
# 44546    -0.10597   -0.964200  -0.030997  0.481468    -0.038749   -0.381587
# 44547    -0.10597   -0.555896   0.400720 -0.808228    -0.038749   -0.233118
# 44548    -0.10597   -0.964200  -0.172606  0.524636    -0.038749   -0.381587
# 44549    -0.10597   -0.954101   0.836116 -1.489935    -0.038749    0.466808
#
#        construction_year  basin_Internal  basin_Lake Nyasa  basin_Lake Rukwa  \
# 0              -1.366788           False             False             False
# 1               0.744365           False             False             False
# 2              -1.366788           False             False             False
# 3              -1.366788           False              True             False
# 4              -1.366788           False             False             False
# ...                  ...             ...               ...               ...
# 44545           0.745416           False             False             False
# 44546          -1.366788            True             False             False
# 44547           0.738060           False             False             False
# 44548          -1.366788            True             False             False
# 44549           0.737010           False             False             False
#
#        ...  source_spring  source_unknown  waterpoint_type_cattle trough  \
# 0      ...          False           False                          False
# 1      ...           True           False                          False
# 2      ...          False           False                          False
# 3      ...           True           False                          False
# 4      ...           True           False                          False
# ...    ...            ...             ...                            ...
# 44545  ...          False           False                          False
# 44546  ...          False           False                          False
# 44547  ...          False           False                          False
# 44548  ...          False           False                          False
# 44549  ...          False           False                          False
#
#        waterpoint_type_communal standpipe  \
# 0                                    True
# 1                                    True
# 2                                    True
# 3                                    True
# 4                                    True
# ...                                   ...
# 44545                                True
# 44546                               False
# 44547                               False
# 44548                               False
# 44549                               False
#
#        waterpoint_type_communal standpipe multiple  waterpoint_type_dam  \
# 0                                            False                False
# 1                                            False                False
# 2                                            False                False
# 3                                            False                False
# 4                                            False                False
# ...                                            ...                  ...
# 44545                                        False                False
# 44546                                         True                False
# 44547                                        False                False
# 44548                                        False                False
# 44549                                        False                False
#
#        waterpoint_type_hand pump  waterpoint_type_improved spring  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                          False                            False
# 4                          False                            False
# ...                          ...                              ...
# 44545                      False                            False
# 44546                      False                            False
# 44547                       True                            False
# 44548                       True                            False
# 44549                       True                            False
#
#        waterpoint_type_other  status_group
# 0                      False             0
# 1                      False             0
# 2                      False             0
# 3                      False             2
# 4                      False             2
# ...                      ...           ...
# 44545                  False             0
# 44546                  False             2
# 44547                  False             2
# 44548                  False             0
# 44549                  False             0
#
# [44550 rows x 214 columns]

# %%
df.status_group.unique()
# Out:
# array([0, 2, 1])

# %%
arrs = [df_train[df_train.status_group == i].reset_index(drop=True) for i in df.status_group.unique()]

# %%
idx = list(arrs[2].index)
arrs_fnr = np.array_split(idx, 6)

# %%
arrs[1]
# Out:
#        amount_tsh  gps_height  longitude  latitude  num_private  population  \
# 0       -0.105970   -0.964200  -0.039499 -1.284573    -0.038749   -0.381587
# 1       -0.105970   -0.964200  -0.366471  1.315739    -0.038749   -0.381587
# 2       -0.105970   -0.964200  -0.132192  0.627503    -0.038749   -0.381587
# 3       -0.105970    0.136634  -0.483281 -0.787769    -0.038749   -0.379466
# 4       -0.105970    0.821951  -0.161925  1.232214    -0.038749    0.678907
# ...           ...         ...        ...       ...          ...         ...
# 17066   -0.105970    0.720957  -0.029773  1.463340    -0.038749    0.678907
# 17067   -0.055929    0.267927  -0.655417  0.253862    -0.038749    0.445599
# 17068    1.228453   -0.661218   0.722973  0.180173    -0.038749   -0.127068
# 17069   -0.105970   -0.964200  -0.030997  0.481468    -0.038749   -0.381587
# 17070   -0.105970   -0.555896   0.400720 -0.808228    -0.038749   -0.233118
#
#        construction_year  basin_Internal  basin_Lake Nyasa  basin_Lake Rukwa  \
# 0              -1.366788           False              True             False
# 1              -1.366788           False             False             False
# 2              -1.366788            True             False             False
# 3               0.718094           False             False             False
# 4               0.746467           False             False             False
# ...                  ...             ...               ...               ...
# 17066           0.721247           False             False             False
# 17067           0.718094           False             False             False
# 17068           0.704433           False             False             False
# 17069          -1.366788            True             False             False
# 17070           0.738060           False             False             False
#
#        ...  source_spring  source_unknown  waterpoint_type_cattle trough  \
# 0      ...           True           False                          False
# 1      ...           True           False                          False
# 2      ...          False           False                          False
# 3      ...          False           False                          False
# 4      ...          False           False                          False
# ...    ...            ...             ...                            ...
# 17066  ...          False           False                          False
# 17067  ...          False           False                          False
# 17068  ...          False           False                          False
# 17069  ...          False           False                          False
# 17070  ...          False           False                          False
#
#        waterpoint_type_communal standpipe  \
# 0                                    True
# 1                                    True
# 2                                   False
# 3                                   False
# 4                                   False
# ...                                   ...
# 17066                               False
# 17067                               False
# 17068                                True
# 17069                               False
# 17070                               False
#
#        waterpoint_type_communal standpipe multiple  waterpoint_type_dam  \
# 0                                            False                False
# 1                                            False                False
# 2                                             True                False
# 3                                            False                False
# 4                                            False                False
# ...                                            ...                  ...
# 17066                                         True                False
# 17067                                         True                False
# 17068                                        False                False
# 17069                                         True                False
# 17070                                        False                False
#
#        waterpoint_type_hand pump  waterpoint_type_improved spring  \
# 0                          False                            False
# 1                          False                            False
# 2                          False                            False
# 3                           True                            False
# 4                          False                            False
# ...                          ...                              ...
# 17066                      False                            False
# 17067                      False                            False
# 17068                      False                            False
# 17069                      False                            False
# 17070                       True                            False
#
#        waterpoint_type_other  status_group
# 0                      False             2
# 1                      False             2
# 2                      False             2
# 3                      False             2
# 4                       True             2
# ...                      ...           ...
# 17066                  False             2
# 17067                  False             2
# 17068                  False             2
# 17069                  False             2
# 17070                  False             2
#
# [17071 rows x 214 columns]

# %%
idx = list(arrs[0].index)
arrs_f = np.array_split(idx, 45)

# %%
idx = list(arrs[1].index)
arrs_nf = np.array_split(idx, 32)

# %%
models = []
preds = []
counters = []
modes = []

for i in range(len(arrs_fnr)):
    estimator = LogisticRegression(solver='liblinear', fit_intercept=False)
    fnr = arrs[2].take(arrs_fnr[i])
    nf = arrs[1].take(arrs_nf[i])
    f = arrs[0].take(arrs_f[i])
    dataframe = pd.concat([fnr, nf, f])
    estimator.fit(dataframe.drop(['status_group'], axis=1), dataframe['status_group'])
    predictions = estimator.predict(df_test.drop(['status_group'], axis=1))
    models.append(estimator)
    preds.append(predictions)
    
for i in range(len(preds[0])):
    mode = md([pred[i] for pred in preds])
    counter = Counter([pred[i] for pred in preds])
    counters.append(counter)
    modes.append(mode)

# %%
pred_df = pd.DataFrame({f"model {n}": preds[n] for n in range(len(preds))})
pred_df['mode'] = modes
pred_df['original'] = df_test['status_group']

# %%
matrix_labels = ['functional', 'functional needs repair', 
                 'non functional']

matrix = pd.DataFrame(confusion_matrix(pred_df['mode'], df_test['status_group']), columns=matrix_labels, index=matrix_labels)
report = pd.DataFrame(classification_report(pred_df['mode'], df_test['status_group'], output_dict=True))

# %%
matrix
# Out:
#                          functional  functional needs repair  non functional
# functional                     5122                      280            1215
# functional needs repair        1886                      677             903
# non functional                  997                      135            3635

# %%
report
# Out:
#                      0            1            2  accuracy     macro avg  \
# precision     0.639850     0.619963     0.631844  0.635286      0.630553
# recall        0.774067     0.195326     0.762534  0.635286      0.577309
# f1-score      0.700588     0.297060     0.691065  0.635286      0.562904
# support    6617.000000  3466.000000  4767.000000  0.635286  14850.000000
#
#            weighted avg
# precision      0.632639
# recall         0.635286
# f1-score       0.603347
# support    14850.000000
